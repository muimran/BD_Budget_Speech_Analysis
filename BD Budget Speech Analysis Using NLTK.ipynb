# %%
# !pip install nltk
# !pip install simple_colors
# Out:
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (3.6.1)
# Requirement already satisfied: regex in c:\programdata\anaconda3\lib\site-packages (from nltk) (2021.4.4)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk) (1.0.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk) (4.59.0)
# Requirement already satisfied: simple_colors in c:\programdata\anaconda3\lib\site-packages (0.1.5)

# %%
from nltk.corpus import PlaintextCorpusReader
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from nltk import FreqDist
import string
from simple_colors import *

# %%
file_path = r"C:\Users\Imran\Documents\Budget Speeches\Splitted\nltk"

# %%
budget_corpus = PlaintextCorpusReader(file_path, '.*')

# %%
budget_corpus.fileids()
# Out:
# ['speech_1997_98.txt',
#  'speech_1998_99.txt',
#  'speech_1999_00.txt',
#  'speech_2000_01.txt',
#  'speech_2001_02.txt',
#  'speech_2002_03.txt',
#  'speech_2003_04.txt',
#  'speech_2004_05.txt',
#  'speech_2005_06.txt',
#  'speech_2006_07.txt',
#  'speech_2007_08.txt',
#  'speech_2008_09.txt',
#  'speech_2009_10.txt',
#  'speech_2010_11.txt',
#  'speech_2011_12.txt',
#  'speech_2012_13.txt',
#  'speech_2013_14.txt',
#  'speech_2014_15.txt',
#  'speech_2015_16.txt',
#  'speech_2016_17.txt',
#  'speech_2017_18.txt',
#  'speech_2018_19.txt',
#  'speech_2019_20.txt',
#  'speech_2020_21.txt',
#  'speech_2021_22.txt']

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Imran\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('english'))
print(len(stop_words))
print (stop_words)
# Out:
# 179
# {'had', 'wouldn', 'o', "she's", 'being', 'haven', "you'd", 'shouldn', 'between', 'shan', 'hasn', 'whom', 'yourself', 'ours', 'than', 'here', "should've", "aren't", 'hadn', 'below', 't', 'it', 'from', 'themselves', "hasn't", 'ma', 'any', 'just', 'him', "you'll", 'because', 'i', 'about', "isn't", 'he', 'on', 'will', 'of', "mustn't", "don't", 'over', 'mustn', "that'll", 'these', 'weren', 'own', "wouldn't", "shouldn't", 'were', 'do', 'd', 'been', 'yours', 'as', 'how', 'itself', 'my', 'don', 'when', 'theirs', 'll', 'other', 'couldn', 'nor', "needn't", 'there', 'few', 'all', 'above', 'didn', "doesn't", 'the', 'both', 'have', 'once', 'can', 'for', 'further', 'an', 'each', "couldn't", 'no', 'mightn', "didn't", 'those', 'having', 'her', 'isn', 'has', 's', 'now', 'hers', 'doesn', 'ourselves', 'again', 'we', 'if', 'this', 'at', 'y', 'where', 'with', 'why', "mightn't", 'they', 'such', "won't", 'in', 'their', 'while', 'them', 'more', 'me', 'after', "weren't", 'our', 'yourselves', 'its', 'so', 'what', 'out', 'a', 'myself', 'was', 'that', 'during', "it's", 'doing', 'under', 'won', 'into', 'but', 'until', 'did', 'your', 'some', 'and', 'aren', 'wasn', 'or', 'are', 'through', "you're", 're', "hadn't", 'then', 'to', 'up', 'should', 'ain', 'too', 'his', 'against', 'm', 'off', 'down', 'before', "shan't", 'only', 'which', 'herself', 'very', 'you', 'is', 'same', 'himself', 'be', "haven't", 'not', "wasn't", 'she', 've', 'who', 'am', 'needn', 'does', 'by', 'most', "you've"}

# %%
#adding my own stop words
stop_words.update(['.', ',', '"', "'", ':', ';', '!', '(', ')', '{', '}', '``', '``', '‘',
                   '[', ']', '•', '’', 'fy', '\uf0d8', 'per', 'cent', 'percent', 'would', 'mr', 'mr.', 'also', '%', 'speaker', 'tk', 'crore', 'sir', "''"])
print(len(stop_words))
# Out:
# 211

# %%
budget_corpus9798 = budget_corpus.raw('speech_1997_98.txt')
budget_corpus9798_low = budget_corpus9798.lower()
word_tokens9798 = word_tokenize(budget_corpus9798_low)
fltrd_sntnc9798 = [word for word in word_tokens9798 if not word in stop_words]
fltrd_sntnc9798_dist= FreqDist(fltrd_sntnc9798)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc9798_dist.plot(10,title='Freq. Dist. of 10 most common words in 1997/98 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 1997/98 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus9899 = budget_corpus.raw('speech_1998_99.txt')
budget_corpus9899_low = budget_corpus9899.lower()
word_tokens9899 = word_tokenize(budget_corpus9899_low)
fltrd_sntnc9899 = [word for word in word_tokens9899 if not word in stop_words]
fltrd_sntnc9899_dist= FreqDist(fltrd_sntnc9899)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc9899_dist.plot(10,title='Freq. Dist. of 10 most common words in 1998/99 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 1998/99 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus9900 = budget_corpus.raw('speech_1999_00.txt')
budget_corpus9900_low = budget_corpus9900.lower()
word_tokens9900 = word_tokenize(budget_corpus9900_low)
fltrd_sntnc9900 = [word for word in word_tokens9900 if not word in stop_words]
fltrd_sntnc9900_dist= FreqDist(fltrd_sntnc9900)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc9900_dist.plot(10,title='Freq. Dist. of 10 most common words in 1999/00 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 1999/00 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus0001 = budget_corpus.raw('speech_2000_01.txt')
budget_corpus0001_low = budget_corpus0001.lower()
word_tokens0001 = word_tokenize(budget_corpus0001_low)
fltrd_sntnc0001 = [word for word in word_tokens0001 if not word in stop_words]
fltrd_sntnc0001_dist= FreqDist(fltrd_sntnc0001)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc0001_dist.plot(10,title='Freq. Dist. of 10 most common words in 2000/01 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2000/01 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus0102 = budget_corpus.raw('speech_2001_02.txt')
budget_corpus0102_low = budget_corpus0102.lower()
word_tokens0102 = word_tokenize(budget_corpus0102_low)
fltrd_sntnc0102 = [word for word in word_tokens0102 if not word in stop_words]
fltrd_sntnc0102_dist= FreqDist(fltrd_sntnc0102)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc0102_dist.plot(10,title='Freq. Dist. of 10 most common words in 2001/02 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2001/02 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus0203 = budget_corpus.raw('speech_2002_03.txt')
budget_corpus0203_low = budget_corpus0203.lower()
word_tokens0203 = word_tokenize(budget_corpus0203_low)
fltrd_sntnc0203 = [word for word in word_tokens0203 if not word in stop_words]
fltrd_sntnc0203_dist= FreqDist(fltrd_sntnc0203)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc0203_dist.plot(10,title='Freq. Dist. of 10 most common words in 2002/03 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2002/03 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus0304 = budget_corpus.raw('speech_2003_04.txt')
budget_corpus0304_low = budget_corpus0304.lower()
word_tokens0304 = word_tokenize(budget_corpus0304_low)
fltrd_sntnc0304 = [word for word in word_tokens0304 if not word in stop_words]
fltrd_sntnc0304_dist= FreqDist(fltrd_sntnc0304)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc0304_dist.plot(10,title='Freq. Dist. of 10 most common words in 2003/04 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2003/04 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus0405 = budget_corpus.raw('speech_2004_05.txt')
budget_corpus0405_low = budget_corpus0405.lower()
word_tokens0405 = word_tokenize(budget_corpus0405_low)
fltrd_sntnc0405 = [word for word in word_tokens0405 if not word in stop_words]
fltrd_sntnc0405_dist= FreqDist(fltrd_sntnc0405)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc0405_dist.plot(10,title='Freq. Dist. of 10 most common words in 2004/05 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2004/05 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
fltrd_sntnc0405_dist.most_common(10)
# Out:
# [('taka', 105),
#  ('tax', 95),
#  ('budget', 88),
#  ('year', 87),
#  ('development', 81),
#  ('government', 67),
#  ('revenue', 47),
#  ('propose', 47),
#  ('fiscal', 43),
#  ('sector', 42)]

# %%
budget_corpus0506 = budget_corpus.raw('speech_2005_06.txt')
budget_corpus0506_low = budget_corpus0506.lower()
word_tokens0506 = word_tokenize(budget_corpus0506_low)
fltrd_sntnc0506 = [word for word in word_tokens0506 if not word in stop_words]
fltrd_sntnc0506_dist= FreqDist(fltrd_sntnc0506)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc0506_dist.plot(10,title='Freq. Dist. of 10 most common words in 2005/06 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2005/06 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus0607 = budget_corpus.raw('speech_2006_07.txt')
budget_corpus0607_low = budget_corpus0607.lower()
word_tokens0607 = word_tokenize(budget_corpus0607_low)
fltrd_sntnc0607 = [word for word in word_tokens0607 if not word in stop_words]
fltrd_sntnc0607_dist= FreqDist(fltrd_sntnc0607)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc0607_dist.plot(10,title='Freq. Dist. of 10 most common words in 2006/07 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2006/07 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus0708 = budget_corpus.raw('speech_2007_08.txt')
budget_corpus0708_low = budget_corpus0708.lower()
word_tokens0708 = word_tokenize(budget_corpus0708_low)
fltrd_sntnc0708 = [word for word in word_tokens0708 if not word in stop_words]
fltrd_sntnc0708_dist= FreqDist(fltrd_sntnc0708)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc0708_dist.plot(10,title='Freq. Dist. of 10 most common words in 2007/08 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2007/08 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus0809 = budget_corpus.raw('speech_2008_09.txt')
budget_corpus0809_low = budget_corpus0809.lower()
word_tokens0809 = word_tokenize(budget_corpus0809_low)
fltrd_sntnc0809 = [word for word in word_tokens0809 if not word in stop_words]
fltrd_sntnc0809_dist= FreqDist(fltrd_sntnc0809)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc0809_dist.plot(10,title='Freq. Dist. of 10 most common words in 2008/09 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2008/09 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus0910 = budget_corpus.raw('speech_2009_10.txt')
budget_corpus0910_low = budget_corpus0910.lower()
word_tokens0910 = word_tokenize(budget_corpus0910_low)
fltrd_sntnc0910 = [word for word in word_tokens0910 if not word in stop_words]
fltrd_sntnc0910_dist= FreqDist(fltrd_sntnc0910)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc0910_dist.plot(10,title='Freq. Dist. of 10 most common words in 2009/10 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2009/10 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus1011 = budget_corpus.raw('speech_2010_11.txt')
budget_corpus1011_low = budget_corpus1011.lower()
word_tokens1011 = word_tokenize(budget_corpus1011_low)
fltrd_sntnc1011 = [word for word in word_tokens1011 if not word in stop_words]
fltrd_sntnc1011_dist= FreqDist(fltrd_sntnc1011)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc1011_dist.plot(10,title='Freq. Dist. of 10 most common words in 2010/11 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2010/11 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
fltrd_sntnc1011_dist.most_common(10)
# Out:
# [('budget', 152),
#  ('development', 129),
#  ('year', 113),
#  ('sector', 110),
#  ('bangladesh', 93),
#  ('government', 92),
#  ('propose', 82),
#  ('country', 81),
#  ('taken', 73),
#  ('order', 67)]

# %%
budget_corpus1112 = budget_corpus.raw('speech_2011_12.txt')
budget_corpus1112_low = budget_corpus1112.lower()
word_tokens1112 = word_tokenize(budget_corpus1112_low)
fltrd_sntnc1112 = [word for word in word_tokens1112 if not word in stop_words]
fltrd_sntnc1112_dist= FreqDist(fltrd_sntnc1112)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc1112_dist.plot(10,title='Freq. Dist. of 10 most common words in 2011/12 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2011/12 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus1213 = budget_corpus.raw('speech_2012_13.txt')
budget_corpus1213_low = budget_corpus1213.lower()
word_tokens1213 = word_tokenize(budget_corpus1213_low)
fltrd_sntnc1213 = [word for word in word_tokens1213 if not word in stop_words]
fltrd_sntnc1213_dist= FreqDist(fltrd_sntnc1213)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc1213_dist.plot(10,title='Freq. Dist. of 10 most common words in 2012/13 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2012/13 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus1314 = budget_corpus.raw('speech_2013_14.txt')
budget_corpus1314_low = budget_corpus1314.lower()
word_tokens1314 = word_tokenize(budget_corpus1314_low)
fltrd_sntnc1314 = [word for word in word_tokens1314 if not word in stop_words]
fltrd_sntnc1314_dist= FreqDist(fltrd_sntnc1314)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc1314_dist.plot(10,title='Freq. Dist. of 10 most common words in 2013/14 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2013/14 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus1415 = budget_corpus.raw('speech_2014_15.txt')
budget_corpus1415_low = budget_corpus1415.lower()
word_tokens1415 = word_tokenize(budget_corpus1415_low)
fltrd_sntnc1415 = [word for word in word_tokens1415 if not word in stop_words]
fltrd_sntnc1415_dist= FreqDist(fltrd_sntnc1415)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc1415_dist.plot(10,title='Freq. Dist. of 10 most common words in 2014/15 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2014/15 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
fltrd_sntnc1415_dist.most_common(10)
# Out:
# [('tax', 158),
#  ('development', 107),
#  ('sector', 94),
#  ('budget', 83),
#  ('government', 80),
#  ('thousand', 78),
#  ('growth', 68),
#  ('year', 67),
#  ('propose', 66),
#  ('income', 63)]

# %%
budget_corpus1516 = budget_corpus.raw('speech_2015_16.txt')
budget_corpus1516_low = budget_corpus1516.lower()
word_tokens1516 = word_tokenize(budget_corpus1516_low)
fltrd_sntnc1516 = [word for word in word_tokens1516 if not word in stop_words]
fltrd_sntnc1516_dist= FreqDist(fltrd_sntnc1516)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc1516_dist.plot(10,title='Freq. Dist. of 10 most common words in 2015/16 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2015/16 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus1617 = budget_corpus.raw('speech_2016_17.txt')
budget_corpus1617_low = budget_corpus1617.lower()
word_tokens1617 = word_tokenize(budget_corpus1617_low)
fltrd_sntnc1617 = [word for word in word_tokens1617 if not word in stop_words]
fltrd_sntnc1617_dist= FreqDist(fltrd_sntnc1617)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc1617_dist.plot(10,title='Freq. Dist. of 10 most common words in 2016/17 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2016/17 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus1718 = budget_corpus.raw('speech_2017_18.txt')
budget_corpus1718_low = budget_corpus1718.lower()
word_tokens1718 = word_tokenize(budget_corpus1718_low)
fltrd_sntnc1718 = [word for word in word_tokens1718 if not word in stop_words]
fltrd_sntnc1718_dist= FreqDist(fltrd_sntnc1718)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc1718_dist.plot(10,title='Freq. Dist. of 10 most common words in 2017/18 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2017/18 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus1819 = budget_corpus.raw('speech_2018_19.txt')
budget_corpus1819_low = budget_corpus1819.lower()
word_tokens1819 = word_tokenize(budget_corpus1819_low)
fltrd_sntnc1819 = [word for word in word_tokens1819 if not word in stop_words]
fltrd_sntnc1819_dist= FreqDist(fltrd_sntnc1819)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc1819_dist.plot(10,title='Freq. Dist. of 10 most common words in 2018/19 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2018/19 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus1920 = budget_corpus.raw('speech_2019_20.txt')
budget_corpus1920_low = budget_corpus1920.lower()
word_tokens1920 = word_tokenize(budget_corpus1920_low)
fltrd_sntnc1920 = [word for word in word_tokens1920 if not word in stop_words]
fltrd_sntnc1920_dist= FreqDist(fltrd_sntnc1920)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc1920_dist.plot(10,title='Freq. Dist. of 10 most common words in 2019/20 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2019/20 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus2021 = budget_corpus.raw('speech_2020_21.txt')
budget_corpus2021_low = budget_corpus2021.lower()
word_tokens2021 = word_tokenize(budget_corpus2021_low)
fltrd_sntnc2021 = [word for word in word_tokens2021 if not word in stop_words]
fltrd_sntnc2021_dist= FreqDist(fltrd_sntnc2021)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc2021_dist.plot(10,title='Freq. Dist. of 10 most common words in 2020/21 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2020/21 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
budget_corpus2122 = budget_corpus.raw('speech_2021_22.txt')
budget_corpus2122_low = budget_corpus2122.lower()
word_tokens2122 = word_tokenize(budget_corpus2122_low)
fltrd_sntnc2122 = [word for word in word_tokens2122 if not word in stop_words]
fltrd_sntnc2122_dist= FreqDist(fltrd_sntnc2122)
plt.rcParams['figure.figsize'] = [14, 6]
fltrd_sntnc2122_dist.plot(10,title='Freq. Dist. of 10 most common words in 2021/22 (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Freq. Dist. of 10 most common words in 2021/22 (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
print(blue('1997/98', 'bold'))
print(fltrd_sntnc9798_dist.most_common(10))
print(blue('1998/99', 'bold'))
print(fltrd_sntnc9899_dist.most_common(10))
print(blue('1999/00', 'bold'))
print(fltrd_sntnc9900_dist.most_common(10))
print(blue('2000/01', 'bold'))
print(fltrd_sntnc0001_dist.most_common(10))
print(blue('2001/02', 'bold'))
print(fltrd_sntnc0102_dist.most_common(10))
print(blue('2002/03', 'bold'))
print(fltrd_sntnc0203_dist.most_common(10))
print(blue('2003/04', 'bold'))
print(fltrd_sntnc0304_dist.most_common(10))
# Out:
# 1997/98
# [('tax', 127), ('government', 91), ('bangladesh', 71), ('development', 71), ('revenue', 67), ('year', 62), ('sector', 61), ('proposed', 59), ('duty', 57), ('budget', 51)]
# 1998/99
# [('tax', 148), ('duty', 101), ('propose', 100), ('rate', 86), ('year', 83), ('budget', 82), ('government', 82), ('revenue', 75), ('sector', 64), ('development', 60)]
# 1999/00
# [('tax', 180), ('duty', 142), ('propose', 123), ('government', 106), ('rate', 99), ('revenue', 78), ('proposed', 75), ('15', 74), ('bangladesh', 73), ('development', 73)]
# 2000/01
# [('taka', 196), ('government', 105), ('tax', 101), ('propose', 88), ('budget', 84), ('bangladesh', 81), ('duty', 78), ('development', 66), ('revenue', 66), ('allocation', 65)]
# 2001/02
# [('development', 82), ('government', 76), ('budget', 64), ('allocation', 62), ('sector', 58), ('bangladesh', 53), ('years', 50), ('year', 48), ('growth', 45), ('?', 44)]
# 2002/03
# [('tax', 271), ('propose', 162), ('government', 144), ('duty', 140), ('budget', 103), ('development', 90), ('economic', 85), ('income', 82), ('present', 78), ('year', 76)]
# 2003/04
# [('government', 141), ('tax', 120), ('budget', 93), ('development', 86), ('propose', 80), ('taka', 76), ('revenue', 72), ('duty', 72), ('year', 69), ('sector', 63)]
